# %% [markdown]
# <a href="https://colab.research.google.com/github/nunocesarsa/CML_Short_tutorial/blob/master/Computer_Vision__Examples_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This exercise is a copy paste from:
#
# https://medium.com/@artinte7/real-time-object-detection-using-yolo-upon-google-colab-in-5-minutes-fd65a4903df5

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# !nvidia-smi
# Out:
# Sun Mar 22 18:04:00 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.64.00    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   42C    P8     7W /  75W |      0MiB /  7611MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# ...

# %% [markdown]
# assign yourself a GPU computer
#
# runtime -> session type -> GPU

# %%
#Importing YOLO

import os
os.environ['PATH'] += ':/usr/local/cuda/bin'
# !git clone https://github.com/AlexeyAB/darknet/
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 20, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 12785 (delta 2), reused 4 (delta 0), pack-reused 12765
# Receiving objects: 100% (12785/12785), 11.76 MiB | 5.96 MiB/s, done.
# Resolving deltas: 100% (8695/8695), done.

# %%
# !apt install gcc-5 g++-5 -y
# !ln -s /usr/bin/gcc-5 /usr/local/cuda/bin/gcc 
# !ln -s /usr/bin/g++-5 /usr/local/cuda/bin/g++
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   cpp-5 gcc-5-base libasan2 libgcc-5-dev libisl15 libmpx0 libstdc++-5-dev
# Suggested packages:
#   gcc-5-locales g++-5-multilib gcc-5-doc libstdc++6-5-dbg gcc-5-multilib
#   libgcc1-dbg libgomp1-dbg libitm1-dbg libatomic1-dbg libasan2-dbg
#   liblsan0-dbg libtsan0-dbg libubsan0-dbg libcilkrts5-dbg libmpx0-dbg
#   libquadmath0-dbg libstdc++-5-doc
# The following NEW packages will be installed:
#   cpp-5 g++-5 gcc-5 gcc-5-base libasan2 libgcc-5-dev libisl15 libmpx0
#   libstdc++-5-dev
# 0 upgraded, 9 newly installed, 0 to remove and 25 not upgraded.
# Need to get 29.1 MB of archives.
# After this operation, 100 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 gcc-5-base amd64 5.5.0-12ubuntu1 [17.1 kB]
# ...

# %%
# %cd darknet
# !sed -i 's/GPU=0/GPU=1/g' Makefile
# !sed -i 's/OPENCV=0/OPENCV=1/g' Makefile
# !make
# Out:
# [Errno 2] No such file or directory: 'darknet'
# /content/darknet
# mkdir -p ./obj/
# mkdir -p backup
# mkdir -p results
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:909:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^
# ...

# %%
# get yolov3 weights
# !wget https://pjreddie.com/media/files/yolov3.weights
# !chmod a+x ./darknet
# Out:
# --2020-03-22 18:05:52--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M  5.22MB/s    in 74s
#
# 2020-03-22 18:07:06 (3.20 MB/s) - ‘yolov3.weights’ saved [248007048/248007048]

# %%
# !pwd
# Out:
# /content/darknet

# %%
# !apt install ffmpeg libopencv-dev libgtk-3-dev python-numpy python3-numpy libdc1394-22 libdc1394-22-dev libjpeg-dev libtiff5-dev libavcodec-dev libavformat-dev libswscale-dev libxine2-dev libgstreamer1.0-dev libgstreamer-plugins-base1.0-dev libv4l-dev libtbb-dev qtbase5-dev libfaac-dev libmp3lame-dev libopencore-amrnb-dev libopencore-amrwb-dev libtheora-dev libvorbis-dev libxvidcore-dev x264 v4l-utils unzip
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libjpeg-dev is already the newest version (8c-2ubuntu8).
# libjpeg-dev set to manually installed.
# libvorbis-dev is already the newest version (1.3.5-4.2).
# libvorbis-dev set to manually installed.
# python-numpy is already the newest version (1:1.13.3-2ubuntu1).
# python-numpy set to manually installed.
# python3-numpy is already the newest version (1:1.13.3-2ubuntu1).
# python3-numpy set to manually installed.
# unzip is already the newest version (6.0-21ubuntu1).
# libdc1394-22 is already the newest version (2.2.5-1).
# libdc1394-22 set to manually installed.
# libdc1394-22-dev is already the newest version (2.2.5-1).
# libdc1394-22-dev set to manually installed.
# libtbb-dev is already the newest version (2017~U7-8).
# libtbb-dev set to manually installed.
# libtiff5-dev is already the newest version (4.0.9-5ubuntu0.3).
# libtiff5-dev set to manually installed.
# ...

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-7ccd2e32-fc3c-45bf-8d4d-aa235d4e5b98" name="files[]" multiple disabled />
#      <output id="result-7ccd2e32-fc3c-45bf-8d4d-aa235d4e5b98">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving goatvid.mp4 to goatvid.mp4

# %%
# !pwd
# Out:
# /content/darknet

# %%
# !./darknet detector demo cfg/coco.data cfg/yolov3.cfg yolov3.weights -dont_show goatvid.mp4 -i 0 -out_filename goat_obj.mp4
# Out:
# Streaming output truncated to the last 5000 lines.
#
#  cvWriteFrame
# Objects:
#
# truck: 60%
# car: 71% , truck: 43%
# truck: 30%
# car: 85%
# car: 96%
# person: 92%
# person: 90%
# person: 84%
# person: 38%
# person: 34%
# person: 26%
#
# FPS:22.5 	 AVG_FPS:22.6
#
#  cvWriteFrame
# Objects:
#
# truck: 38%
# car: 84% , truck: 35%
# car: 96%
# car: 89%
# person: 96%
# person: 94%
# person: 70%
# person: 64%
# person: 62%
# person: 31%
#
# FPS:22.3 	 AVG_FPS:22.6
#
#  cvWriteFrame
# Objects:
#
# truck: 61%
# car: 70% , truck: 57%
# car: 69% , truck: 56%
# car: 98%
# person: 96%
# person: 94%
# person: 60%
# person: 27%
#
# FPS:22.1 	 AVG_FPS:22.6
#
#  cvWriteFrame
# Objects:
#
# truck: 53%
# truck: 43%
# car: 79%
# car: 75% , truck: 37%
# car: 99%
# person: 92%
# person: 92%
# person: 64%
# person: 31%
#
# FPS:22.0 	 AVG_FPS:22.6
#
#  cvWriteFrame
# Objects:
#
# horse: 26%
# dog: 52%
# truck: 61%
# car: 76% , truck: 40%
# car: 76%
# truck: 29%
# car: 99%
# person: 96%
# person: 86%
# ...

# %% [markdown]
# #downoad the output

# %% [markdown]
# The following examples are from the guys colab repository

# %%
#output_video_name = "doggie.mp4"
#%cd ..
# !./darknet detector demo cfg/coco.data cfg/yolov3.cfg yolov3.weights -dont_show doggy.mp4 -i 0 -out_filename out.avi -thresh 0.7

# %%
#examole of image detection so-called 'easy-one'
# !./darknet detect cfg/yolov3.cfg yolov3.weights data/dog.jpg

# %%
import cv2
import matplotlib.pyplot as plt
import os.path

fig,ax = plt.subplots()
ax.tick_params(labelbottom="off",bottom="off")
ax.tick_params(labelleft="off",left="off")
ax.set_xticklabels([]) 
ax.axis('off')

file = './predictions.jpg'
if os.path.exists(file):
  img = cv2.imread(file)
  show_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) 
  plt.imshow(show_img)
